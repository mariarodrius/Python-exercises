# %%
import math

# %%
for number in range (100):
    squareroot=math.sqrt(number)
    print (number, ":", squareroot)
# Out:
# 0 : 0.0
# 1 : 1.0
# 2 : 1.4142135623730951
# 3 : 1.7320508075688772
# 4 : 2.0
# 5 : 2.23606797749979
# 6 : 2.449489742783178
# 7 : 2.6457513110645907
# 8 : 2.8284271247461903
# 9 : 3.0
# 10 : 3.1622776601683795
# 11 : 3.3166247903554
# 12 : 3.4641016151377544
# 13 : 3.605551275463989
# 14 : 3.7416573867739413
# 15 : 3.872983346207417
# 16 : 4.0
# 17 : 4.123105625617661
# 18 : 4.242640687119285
# 19 : 4.358898943540674
# 20 : 4.47213595499958
# 21 : 4.58257569495584
# 22 : 4.69041575982343
# 23 : 4.795831523312719
# 24 : 4.898979485566356
# 25 : 5.0
# 26 : 5.0990195135927845
# 27 : 5.196152422706632
# 28 : 5.291502622129181
# 29 : 5.385164807134504
# 30 : 5.477225575051661
# 31 : 5.5677643628300215
# 32 : 5.656854249492381
# 33 : 5.744562646538029
# 34 : 5.830951894845301
# 35 : 5.916079783099616
# 36 : 6.0
# 37 : 6.082762530298219
# 38 : 6.164414002968976
# 39 : 6.244997998398398
# 40 : 6.324555320336759
# 41 : 6.4031242374328485
# 42 : 6.48074069840786
# 43 : 6.557438524302
# ...

# %%
def was_it_sunny(it_was):
    if it_was == True:
        print('Yes')
    else:
        print('No')
    #return #was_it_sunny #what exactly does this do here?
was_it_sunny(False)
print(was_it_sunny(True))
print(was_it_sunny(False))
# Out:
# No
# Yes
# None
# No
# None

# %%
was_it_sunny(False)
# Out:
# No

# %%
print(was_it_sunny(True))
print(was_it_sunny(False))
#with return was_it_sunny from above, instead of None we get <function was_it_sunny at 0x00000299BBB4D550> (whatever that means)
# Out:
# Yes
# None
# No
# None
