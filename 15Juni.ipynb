# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns

# %%
df = pd.read_excel('ITA_short.xlsx')
df
# Out:
#                                                 Item         2002  \
# 0                                              TOTAL -35876109830
# 1                 994--Estimated Low Value Shipments    623484621
# 2  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...     15113368
# 3    984--Estimate Of Low Valued Import Transactions  -1172025052
# 4                             971--Gold; Nonmonetary     17811824
# 5                   961--Coin (Other Than Gold Coin)      -675561
# 6                           950--Coin Including Gold     -3312943
# 7   931--Special Transactions Not Classified By Kind  -1612037116
# 8           899--Miscellaneous Manufactured Articles    -51441668
#
#           2003         2004         2005
# 0 -39280825289 -45849692767 -50567215101
# 1    678119775    695549518    741823127
# 2      8010114      4729046      4994816
# 3  -1312534635  -1487019545  -1633399445
# 4     27014109     14962071    129760760
# 5       470266       192494     -1158537
# ...

# %%
newdf=pd.melt(df, id_vars = 'Item',var_name='Year', value_name ='No of Transactions')
newdf
sns.scatterplot(x ='Item', y ='No of Transactions', data = newdf, palette ='plasma')
plt.legend(labels=["Line1","Line2", "Line3", "Line4", "Line5", "Line6", "Line7", "Line8"])

# %%
newdf["No of Transactions"]=newdf["No of Transactions"]/1000000
newdf
# Out:
#                                                  Item  Year  \
# 0                                               TOTAL  2002
# 1                  994--Estimated Low Value Shipments  2002
# 2   992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...  2002
# 3     984--Estimate Of Low Valued Import Transactions  2002
# 4                              971--Gold; Nonmonetary  2002
# 5                    961--Coin (Other Than Gold Coin)  2002
# 6                            950--Coin Including Gold  2002
# 7    931--Special Transactions Not Classified By Kind  2002
# 8            899--Miscellaneous Manufactured Articles  2002
# 9                                               TOTAL  2003
# 10                 994--Estimated Low Value Shipments  2003
# 11  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...  2003
# 12    984--Estimate Of Low Valued Import Transactions  2003
# 13                             971--Gold; Nonmonetary  2003
# 14                   961--Coin (Other Than Gold Coin)  2003
# ...

# %%
newdf=newdf.round(1)
newdf
# Out:
#                                                  Item  Year  \
# 0                                               TOTAL  2002
# 1                  994--Estimated Low Value Shipments  2002
# 2   992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...  2002
# 3     984--Estimate Of Low Valued Import Transactions  2002
# 4                              971--Gold; Nonmonetary  2002
# 5                    961--Coin (Other Than Gold Coin)  2002
# 6                            950--Coin Including Gold  2002
# 7    931--Special Transactions Not Classified By Kind  2002
# 8            899--Miscellaneous Manufactured Articles  2002
# 9                                               TOTAL  2003
# 10                 994--Estimated Low Value Shipments  2003
# 11  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...  2003
# 12    984--Estimate Of Low Valued Import Transactions  2003
# 13                             971--Gold; Nonmonetary  2003
# 14                   961--Coin (Other Than Gold Coin)  2003
# ...

# %%
sns.stripplot(x ='Year', y ='No of Transactions', hue="Item", data = newdf, palette ='plasma')
#sns.relplot(data=tips, x="total_bill", y="tip", hue="day")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='No of Transactions'>

# %%
data1=newdf.drop([0, 9, 18, 27])

# %%
data1
# Out:
#                                                  Item  Year  \
# 1                  994--Estimated Low Value Shipments  2002
# 2   992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...  2002
# 3     984--Estimate Of Low Valued Import Transactions  2002
# 4                              971--Gold; Nonmonetary  2002
# 5                    961--Coin (Other Than Gold Coin)  2002
# 6                            950--Coin Including Gold  2002
# 7    931--Special Transactions Not Classified By Kind  2002
# 8            899--Miscellaneous Manufactured Articles  2002
# 10                 994--Estimated Low Value Shipments  2003
# 11  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...  2003
# 12    984--Estimate Of Low Valued Import Transactions  2003
# 13                             971--Gold; Nonmonetary  2003
# 14                   961--Coin (Other Than Gold Coin)  2003
# 15                           950--Coin Including Gold  2003
# 16   931--Special Transactions Not Classified By Kind  2003
# ...

# %%
sns.barplot(x ='Year', y ='No of Transactions', hue='Item', data = data1, palette ='plasma')
#plt.legend(labels=["Line1","Line2", "Line3", "Line4", "Line5", "Coin Including Gold", "Line7", "Line8"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='No of Transactions'>

# %%
df
# Out:
#                                                 Item         2002  \
# 0                                              TOTAL -35876109830
# 1                 994--Estimated Low Value Shipments    623484621
# 2  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...     15113368
# 3    984--Estimate Of Low Valued Import Transactions  -1172025052
# 4                             971--Gold; Nonmonetary     17811824
# 5                   961--Coin (Other Than Gold Coin)      -675561
# 6                           950--Coin Including Gold     -3312943
# 7   931--Special Transactions Not Classified By Kind  -1612037116
# 8           899--Miscellaneous Manufactured Articles    -51441668
#
#           2003         2004         2005
# 0 -39280825289 -45849692767 -50567215101
# 1    678119775    695549518    741823127
# 2      8010114      4729046      4994816
# 3  -1312534635  -1487019545  -1633399445
# 4     27014109     14962071    129760760
# 5       470266       192494     -1158537
# ...

# %%
sns.relplot(data=data1, x="Year", y="No of Transactions", hue="Item", palette ='plasma', kind='line') 
#https://towardsdatascience.com/master-a-third-of-seaborn-statistical-plotting-with-relplot-df8642718f0f
#plt.xlim(2002, 2005)
#plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.xticks(np.arange(2002, 2006, 1))
plt.xticks(rotation=60)
# Out:
# (array([2002, 2003, 2004, 2005]),
#  [Text(2001.5, 0, '2001.5'),
#   Text(2002.0, 0, '2002.0'),
#   Text(2002.5, 0, '2002.5'),
#   Text(2003.0, 0, '2003.0')])

# %%
fg = sns.relplot()
print(type(fg))
plot = sns.scatterplot()
print(type(plot))
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
sns.relplot(x='Year',
            y='No of Transactions',
            data=data1,
            hue='Item',
            kind='scatter',
            palette='crest',
            col='Item',
            col_wrap=4);
#hue='Item',
#col_wrap states how many columns we want in a row 
#plt.xticks(rotation=60) to show rotated x-axix tick points

# %%
#pd.read_csv(parse_dates=['Year'], index_col='Year')

# %%
print(data1.info())  #Year is parsed as object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 35
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item                32 non-null     object
#  1   Year                32 non-null     object
#  2   No of Transactions  32 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 2.0+ KB
# None

# %%
print(type(data1["Year"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#pd.read_csv('data/data_1.csv', 
#            parse_dates=['date'], 
#            dayfirst=True)  #to format DD/MM

#https://www.marsja.se/pandas-convert-column-to-datetime/
data1['Year'] = pd.to_datetime(data1['Year'])
print(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 35
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Item                32 non-null     object
#  1   Year                32 non-null     datetime64[ns]
#  2   No of Transactions  32 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 2.0+ KB
# None

# %%
sns.relplot(x='Year', y='No of Transactions', 
            data=data1, kind='line');

# %%
print(data1.index)
# Out:
# Int64Index([ 1,  2,  3,  4,  5,  6,  7,  8, 10, 11, 12, 13, 14, 15, 16, 17, 19,
#             20, 21, 22, 23, 24, 25, 26, 28, 29, 30, 31, 32, 33, 34, 35],
#            dtype='int64')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#sns.relplot(x=data1.index, y='No of Transactions', 
#            data=data1, kind='line');
#ValueError: cannot reindex on an axis with duplicate labels

# %%
#data1.set_index("Year", inplace = True)
#print(data2.index)

# %%
data1 = data1.reset_index()
data1.rename(columns={'index': 'Year'}, inplace=True)
data1
# Out:
#     Year                                               Item  \
# 0   2002                 994--Estimated Low Value Shipments
# 1   2002  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...
# 2   2002    984--Estimate Of Low Valued Import Transactions
# 3   2002                             971--Gold; Nonmonetary
# 4   2002                   961--Coin (Other Than Gold Coin)
# 5   2002                           950--Coin Including Gold
# 6   2002   931--Special Transactions Not Classified By Kind
# 7   2002           899--Miscellaneous Manufactured Articles
# 8   2003                 994--Estimated Low Value Shipments
# 9   2003  992--EXPORTS NOT OVER $10;000(TO 3/98) $20;000...
# 10  2003    984--Estimate Of Low Valued Import Transactions
# 11  2003                             971--Gold; Nonmonetary
# 12  2003                   961--Coin (Other Than Gold Coin)
# 13  2003                           950--Coin Including Gold
# 14  2003   931--Special Transactions Not Classified By Kind
# ...

# %%
sns.relplot(x=data1.index, y='No of Transactions', 
            data=data1, kind='line');

# %%
print(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                32 non-null     int64
#  1   Item                32 non-null     object
#  2   No of Transactions  32 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 896.0+ bytes
# None
