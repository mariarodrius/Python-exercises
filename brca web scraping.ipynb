# %%
#https://www.kaggle.com/discussions/questions-and-answers/270103 
#Web Scraping with Pandas

import pandas as pd

# %%
url = "https://research.nhgri.nih.gov/projects/bic/Member/cgi-bin/bic_data_condensed.cgi?table=brca2_exons&&exact_search=0&aa_change=2647"
#https://research.nhgri.nih.gov/projects/bic/Member/cgi-bin/bic_data_condensed.cgi?table=brca2_exons
#https://brcaexchange.org/variants?search=brca2&filter%5B%5D=Gene_Symbol&filter%5B%5D=Pathogenicity_expert&filterValue%5B%5D=BRCA2&filterValue%5B%5D=Pathogenic&page=5&orderBy=HGVS_cDNA&order=descending
df = pd.read_html(url, header=0)

# %%
#to check how many tables there are:
len(df)
# Out:
# 1

# %%
#access the table with index:
df[0]
# Out:
#   Frame Shift Mutations Frame Shift Mutations.1 Frame Shift Mutations.2  \
# 0    # of timesRecorded                    Exon                      NT
# 1    # of timesRecorded                    Exon                      NT
# 2                     2                      16                    7917
# 3                     1                      16                    7989
# 4                     2                      16                    7990
# 5                     6                      16                    7990
# 6                     2                      17                    8034
# 7                     1                      17                    8075
# 8                     1                      17                    8149
# 9                     2                      17                    8162
#
#   Frame Shift Mutations.3 Frame Shift Mutations.4 Frame Shift Mutations.5  \
# 0                   Codon             Base Change               AA Change
# ...

# %%
data = df[0]
